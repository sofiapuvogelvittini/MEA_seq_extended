# %%
library(rsconnect)

# %%
rsconnect::setAccountInfo(name='nadifkasrilab',
			  token='secret',
			  secret='secret')

# %%
rsconnect::deployApp(
    appName = "MEA-seq-visualizer",
    account = "nadifkasrilab"
)
# Out:
# ── Preparing for deployment ────────────────────────────────────────────────────────────────────────────────────────────
#
# ✔ Deploying "MEA-seq-visualizer" using "server: shinyapps.io / username: nadifkasrilab"
#
# ℹ Creating application on server...
#
# ✔ Created application with id 16137400
#
# ℹ Bundling 3 files: .ipynb_checkpoints/deploy-checkpoint.ipynb, app.R, and deploy.ipynb
#
# ℹ Capturing R dependencies
#
# ✔ Found 77 dependencies
#
# ✔ Created 42,437b bundle
#
# ℹ Uploading bundle...
#
# ✔ Uploaded bundle with id 11212982
#
# ── Deploying to server ─────────────────────────────────────────────────────────────────────────────────────────────────
# Waiting for task: 1619500688
#   building: Building image: 13886237
#   building: Fetching packages
#   building: Installing packages
#   building: Installing files
#   building: Pushing image: 13886237
#   deploying: Starting instances
#   success: Stopping old instances
# ...
