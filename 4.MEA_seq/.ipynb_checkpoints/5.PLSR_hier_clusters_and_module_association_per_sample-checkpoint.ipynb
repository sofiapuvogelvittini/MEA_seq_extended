# %%
setwd("T:/PIgroup Nael NadifKasri/Sofia/2025/MEA_seq_patient/Analysis/MEA-seq/WGCNA_sPLSR")

# %%
library(tibble)
library(dplyr)
library(tidyr)
library(ggplot2)
library(tidyverse)
library(DESeq2)
library(tidyverse)
library(WGCNA)
library(mixOmics)
library(writexl)
library(RColorBrewer)
library(stringr)
library(pheatmap)
library(reshape2)
# Out:
# Attaching package: 'reshape2'
#
#
# The following object is masked from 'package:tidyr':
#
#     smiths

# %%
MEA_var<-read.csv("T:/PIgroup Nael NadifKasri/Sofia/2025/MEA_seq_patient/Analysis/MEA-seq/patients_normalized_hier_PC13.csv")
mea_seq_samples<-MEA_var$sample
MEA_var<-MEA_var[-length(MEA_var)]#remove cluster variable, not used for this analysis

# %%
counts<-read.table("T:/PIgroup Nael NadifKasri/Sofia/2025/MEA_seq_patient/Analysis/RNA-seq/PRPS_integration_neurons/ruviii.2000.norm_voom.txt")
rownames(counts)<-counts$Gene
counts <- counts[, -ncol(counts)]
#replace "." to "-" for colnames
colnames_counts<-colnames(counts)
colnames_counts<-gsub("\\.", "-", colnames_counts)
colnames_counts<-str_replace_all(colnames_counts, "SMARCB1_KSS_CRISPR", "SMARCB1_KSS-CRISPR") #to align 
colnames(counts)<-colnames_counts

samples_info<-read.csv("T:/PIgroup Nael NadifKasri/Sofia/2025/MEA_seq_patient/Code/0.Data/RNAseq_data/samples_info.csv")
samples_info$Well_ID <- sub(".*_", "", samples_info$sample)
rownames(samples_info)<-samples_info$sample
sampleTable<-samples_info
sampleTable_measeq<-sampleTable[mea_seq_samples,]
sampleTable_measeq$syndrome <- factor(sampleTable_measeq$syndrome, levels = c("control", setdiff(unique(sampleTable_measeq$syndrome), "control")))

sampleTable_measeq <- sampleTable_measeq[order(sampleTable_measeq$syndrome, sampleTable_measeq$group), , drop = FALSE]
samples_order<-sampleTable_measeq$sample

# %%
cell_lines<-read.csv("T:/PIgroup Nael NadifKasri/Sofia/2025/MEA_seq_patient/Code/0.Data/cell_lines/cell_lines.csv")
MEA_var$cell_line<-cell_lines$cell_line_v2[match(MEA_var$Phenotype,cell_lines$Phenotype)]
MEA_var$sample_show<-paste0(MEA_var$cell_line,"_",MEA_var$Well_Label)

# %%
rownames(MEA_var)<-MEA_var$sample

MEA_var_num<-MEA_var %>% select_if(is.numeric)

# %%
freq_WGCNA<-read.table("freq_WGCNA_1C_X40_Y10_10000.txt")
freq_MEA<-read.table("freq_MEA_1C_X40_Y10_10000.txt")

# %%
# Choose stable genes: e.g., selected in >= 50% of bootstraps
n_boot <- 10000
stable_WGCNA <- freq_WGCNA[freq_WGCNA$Freq >= 0.97*n_boot ,"Var1"]
#stable_WGCNA2 <- names(freq_WGCNA2[freq_WGCNA2 >= 0.5*n_boot])
stable_MEA <-freq_MEA[freq_MEA$Freq >= 0.1*n_boot ,"Var1"]

# %%
module_eigengenes<-read.csv("T:/PIgroup Nael NadifKasri/Sofia/2025/MEA_seq_patient/Analysis/RNA-seq/PRPS_integration_neurons/WGCNA/module_eigengenes_NT_signed_sp16.csv")
rownames(module_eigengenes)<-module_eigengenes$X
module_eigengenes<-module_eigengenes[mea_seq_samples,]
module_eigengenes<-drop_na(module_eigengenes)
module_eigengenes<-module_eigengenes[-1]
relevant_module_eigengenes<-module_eigengenes[,stable_WGCNA]

# %%
#Cluster samples based on their trasncriptome loading, and see how activity looks like

# %%
sample_loadings<-read.csv("sample_loadings.csv")
sample_loadings<-sample_loadings[,c("sample","Transcriptome","Activity")]
sample_loadings$sample_show<-MEA_var$sample_show[match(sample_loadings$sample,MEA_var$sample)]
rownames(sample_loadings)<-sample_loadings$sample_show

# %%
heatmap_data<-sample_loadings
# Compute distances based on Transcriptome
d <- dist(heatmap_data[, "Transcriptome", drop = FALSE])

# Hierarchical clustering
hc <- hclust(d, method = "complete")
# Step 3: Plot dendrogram
plot(hc, main = "Hierarchical Clustering (Transcriptome)", xlab = "Samples")

# Draw rectangles around 4 clusters
rect.hclust(hc, k = 4, border = 2:5)  # colors 2,3,4,5
clusters <- cutree(hc, k = 4)
# Out:
# Plot with title "Hierarchical Clustering (Transcriptome)"

# %%
getwd()
# Out:
# [1] "T:/PIgroup Nael NadifKasri/Sofia/2025/MEA_seq_patient/Analysis/MEA-seq/WGCNA_sPLSR"

# %%
p<-pheatmap(heatmap_data[, c("Transcriptome","Activity"), drop = FALSE],
         cluster_rows = hc,   # use the clustering we just computed
         cluster_cols = FALSE,  # do not cluster columns
         scale = "none",         # optional: scale per sample
         show_rownames = TRUE,
               color = colorRampPalette(c("blue", "white", "red"))(100),

            angle_col = 90)
 ggsave("heatmap_Trasncriptome_with_Activity_components.pdf",bg = "transparent",
                   width = 4,   # inches
                   height = 7,   # inches
                 plot=p
         )
p
# Out:
# plot without title

# %%
row_order <- p$tree_row$order  # numeric indices of rows in the clustered order
row_names_ordered <- p$tree_row$labels[row_order]  # sample names in order
row_names_ordered<-MEA_var$sample[match(row_names_ordered,MEA_var$sample_show)]

# %%
#normalized expression
#yes show heatm. order samples based on hier clustering on the MEA? but include them all...
relevant_modules<-colnames(relevant_module_eigengenes)
norm_df<-read.table("T:/PIgroup Nael NadifKasri/Sofia/2025/MEA_seq_patient/Analysis/RNA-seq/PRPS_integration_neurons/PRPS_voom_norm_control.txt")
norm_df_samples<-gsub("\\.", "-", colnames(norm_df))
colnames(norm_df)<-norm_df_samples
gsg <- goodSamplesGenes(t(norm_df))
#summary(gsg)

gsg$allOK

# table(gsg$goodGenes)
# table(gsg$goodSamples)
norm_df <- norm_df[gsg$goodGenes == TRUE,]
norm.counts<-t(norm_df)
norm.counts_df<-as.data.frame(norm.counts)

samples_order<-row_names_ordered
norm.counts_df<-as.data.frame(norm.counts)
norm.counts_df = norm.counts_df[match(samples_order, rownames(norm.counts_df)),]
norm.counts_df_corder<-norm.counts_df[samples_order,]
norm.counts_df_corder_sc<-scale(norm.counts_df_corder) #scale again?
#norm.counts_df_corder_nosc<-
genes_modules<-read.csv("T:/PIgroup Nael NadifKasri/Sofia/2025/MEA_seq_patient/Analysis/RNA-seq/PRPS_integration_neurons/WGCNA/genes_modules_sp16.csv")
rownames(genes_modules)<-genes_modules$X
genes_modules<-genes_modules[-1]
genes_modules$module<-paste0("ME",genes_modules$module)
genes_modules<-genes_modules[genes_modules$module %in% relevant_modules,]
genes_modules<-droplevels(genes_modules)
genes_modules_s<-split(genes_modules,f=genes_modules$module)
MM_list<-genes_modules_s[relevant_modules]
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE

# %%
full_signature<-lapply(MM_list, function(x) x[, "gene"])
full_signature<-unlist(full_signature, use.names=FALSE)

# %%
relevant_module_eigengenes<-relevant_module_eigengenes[row_names_ordered,]

# %%
relevant_module_eigengenes$sample<-rownames(relevant_module_eigengenes)
relevant_module_eigengenes$sample_show<-MEA_var$sample_show[match(relevant_module_eigengenes$sample,MEA_var$sample)]
rownames(relevant_module_eigengenes)<-relevant_module_eigengenes$sample_show

# %%
relevant_module_eigengenes<-relevant_module_eigengenes[-c(8,9)]

# %%
# Determine the max absolute value for symmetric color scaling
max_val <- max(abs(relevant_module_eigengenes), na.rm = TRUE)

p<- pheatmap(relevant_module_eigengenes,
              scale = "none",
              cluster_rows = FALSE,
              cluster_cols = TRUE,
              clustering_distance_cols = "euclidean",
              clustering_method = "complete",
              color = colorRampPalette(c("blue","white","red"))(100),
              breaks = seq(-0.3, 0.3, length.out = 101),  # symmetric breaks
              show_rownames = TRUE,
              show_colnames = TRUE,
            angle_col = 90)

#ggsave("heatmap_gene_modules_noscaled_limits.pdf",bg = "transparent",
                  #width = 5.3,   # inches
 #                 height = 7,   # inches
                #plot=p
        #)
p
# Out:
# plot without title

# %%
colnames(relevant_module_eigengenes)[p$tree_col$order]
# Out:
# [1] "MElightcyan"     "MElightgreen"    "MEorangered4"    "MEdarkorange"
# [5] "MEsienna3"       "MEdarkmagenta"   "MEdarkturquoise"

# %%
clusters
# Out:
#      ARID1B_3_A1      ARID1B_3_A2      ARID1B_3_A3     SMARCB1_1_A8
#                1                1                1                2
#      ARID1B_3_B1      ARID1B_3_B2      ARID1B_3_B3     SMARCB1_1_B8
#                1                1                1                2
#     SMARCB1_2_C7     SMARCB1_2_D5     SMARCB1_2_D7     SMARCB1_1_D8
#                2                2                1                2
# SMARCB1_1_KSS_E1 SMARCB1_1_KSS_E2 SMARCB1_1_KSS_E3 SMARCB1_2_KSS_E5
#                3                3                3                3
# SMARCB1_2_KSS_E6 SMARCB1_1_KSS_F2 SMARCB1_1_KSS_F3 SMARCB1_2_KSS_F5
#                3                3                3                3
# SMARCB1_2_KSS_F6 SMARCB1_2_KSS_F7 SMARCB1_2_KSS_F8         YY1_1_A5
#                3                3                3                4
#         YY1_1_A6        ADNP_1_B4         YY1_1_B6        ADNP_1_C3
#                4                4                4                4
#        ADNP_1_C4    EHMT1_4_KS_D7    EHMT1_4_KS_D8        CHD8_1_E4
#                4                1                1                3
#    EHMT1_4_KS_E7    EHMT1_4_KS_E8        CHD8_1_F3        CHD8_1_F4
#                1                1                3                3

# %%
# Split samples by cluster
trn_clusters <- split(names(clusters), clusters)

# Rename list elements
names(trn_clusters) <- paste0("clust", names(trn_clusters))

# View result
trn_clusters
# Out:
# $clust1
#  [1] "ARID1B_3_A1"   "ARID1B_3_A2"   "ARID1B_3_A3"   "ARID1B_3_B1"
#  [5] "ARID1B_3_B2"   "ARID1B_3_B3"   "SMARCB1_2_D7"  "EHMT1_4_KS_D7"
#  [9] "EHMT1_4_KS_D8" "EHMT1_4_KS_E7" "EHMT1_4_KS_E8"
#
# $clust2
# [1] "SMARCB1_1_A8" "SMARCB1_1_B8" "SMARCB1_2_C7" "SMARCB1_2_D5" "SMARCB1_1_D8"
#
# $clust3
#  [1] "SMARCB1_1_KSS_E1" "SMARCB1_1_KSS_E2" "SMARCB1_1_KSS_E3" "SMARCB1_2_KSS_E5"
#  [5] "SMARCB1_2_KSS_E6" "SMARCB1_1_KSS_F2" "SMARCB1_1_KSS_F3" "SMARCB1_2_KSS_F5"
#  [9] "SMARCB1_2_KSS_F6" "SMARCB1_2_KSS_F7" "SMARCB1_2_KSS_F8" "CHD8_1_E4"
# [13] "CHD8_1_F3"        "CHD8_1_F4"
#
# $clust4
# [1] "YY1_1_A5"  "YY1_1_A6"  "ADNP_1_B4" "YY1_1_B6"  "ADNP_1_C3" "ADNP_1_C4"

# %%
#remove the sample with different genotype 'SMARCB1_2_D7' from $clust1
trn_clusters$clust1 <- setdiff(trn_clusters$clust1, "SMARCB1_2_D7")

# %%
sampleTable_measeq$sample_show<-MEA_var$sample_show[match(sampleTable_measeq$sample,MEA_var$sample)]
rownames(sampleTable_measeq)<-sampleTable_measeq$sample_show

# %%
# ---------------------------
# Compute SD thresholds as before
ME_sd <- apply(module_eigengenes, 2, sd, na.rm = TRUE)
ME_sd_th <- mean(ME_sd) * 0.5  # general median

ME_sd <- apply(relevant_module_eigengenes, 2, sd, na.rm = TRUE)
ME_sd_th_module <- ME_sd * 0.3  # 30% of module SD

# ---------------------------
# Function: run one-sample t-test per cluster
test_cluster_ttest_consistent <- function(cluster_name, cluster_samples, ME_matrix, sampleTable_measeq, prop_threshold = 0.8) {
  
  # 1. subset eigengenes for cluster
  ME_sub <- ME_matrix[cluster_samples, , drop = FALSE]
  
  # 2. One-sample t-test per module
  results <- apply(ME_sub, 2, function(x) {
    tt <- t.test(x, mu = 0)
    c(mean = mean(x), p = tt$p.value)
  })
  
  df <- as.data.frame(t(results))
  df$module <- rownames(df)
  df$p_adj <- p.adjust(df$p, method = "fdr")
  df$threshold <- ME_sd_th_module[as.character(df$module)]
  
  # assign direction based on mean
  df <- df %>%
    mutate(direction = case_when(
      p < 0.05 & mean > threshold  ~ "up",
      p < 0.05 & mean < -threshold  ~ "down",
      TRUE ~ "ns"
    ))
  
  # 3. Prepare ME_df with sample and group info
  ME_df <- ME_sub %>%
    as.data.frame() %>%
    rownames_to_column("sample_show") %>%
    left_join(sampleTable_measeq[, c("sample_show", "group")], by = "sample_show")
  
  # 4. Compute per-cell-line proportion-based consistency
  group_sign <- function(x, prop_threshold) {
    prop_pos <- mean(x > 0, na.rm = TRUE)
    prop_neg <- mean(x < 0, na.rm = TRUE)
    
    if (prop_pos >= prop_threshold) {
      "up"
    } else if (prop_neg >= prop_threshold) {
      "down"
    } else {
      "mixed"
    }
  }
  
  ME_by_group <- ME_df %>%
    group_by(group) %>%
    summarise(across(where(is.numeric), ~ group_sign(.x, prop_threshold)), .groups = "drop")
  
  print(ME_by_group, width = Inf)
  
  # 5. Across-group consistency
  consistency <- apply(ME_by_group[,-1], 2, function(vals) {
    if (all(vals == "up")) {
      "up"
    } else if (all(vals == "down")) {
      "down"
    } else {
      "mixed"
    }
  })
  
  df$consistent_direction <- consistency[df$module]
  
  # stricter significance: t-test significant AND consistent across groups
  df <- df %>%
    mutate(consistent_significance = case_when(
      direction == "up" & consistent_direction == "up" ~ "up",
      direction == "down" & consistent_direction == "down" ~ "down",
      TRUE ~ "ns"
    ))
  
  # assign cluster name
  df$cluster <- cluster_name
  
  df
}

# ---------------------------
# Run for all clusters
cluster_results <- purrr::imap(trn_clusters, 
                                ~ test_cluster_ttest_consistent(.y, .x,
                                    ME_matrix = relevant_module_eigengenes,
                                    sampleTable_measeq = sampleTable_measeq,
                                    prop_threshold = 0.8))  # 80% replicates agreement

cluster_results <- do.call(rbind, cluster_results)
write.csv(cluster_results,"gene_modules_cluster_ttestth_sd03_prop08.csv")
# Out:
# # A tibble: 2 × 8
#   group           MEdarkmagenta MEdarkorange MEdarkturquoise MElightcyan
#   <chr>           <chr>         <chr>        <chr>           <chr>
# 1 ARID1B_CRISPR_1 down          up           mixed           mixed
# 2 EHMT1_CR        mixed         down         down            mixed
#   MElightgreen MEorangered4 MEsienna3
#   <chr>        <chr>        <chr>
# 1 mixed        up           down
# 2 down         up           down
# # A tibble: 2 × 8
#   group              MEdarkmagenta MEdarkorange MEdarkturquoise MElightcyan
#   <chr>              <chr>         <chr>        <chr>           <chr>
# 1 SMARCB1_CSS        down          down         down            down
# 2 SMARCB1_CSS-CRISPR down          up           down            down
#   MElightgreen MEorangered4 MEsienna3
#   <chr>        <chr>        <chr>
# 1 down         up           up
# 2 down         down         down
# # A tibble: 3 × 8
#   group              MEdarkmagenta MEdarkorange MEdarkturquoise MElightcyan
#   <chr>              <chr>         <chr>        <chr>           <chr>
# 1 CHD8_C3            mixed         up           up              up
# 2 SMARCB1_KSS        up            up           up              down
# 3 SMARCB1_KSS-CRISPR up            up           mixed           down
#   MElightgreen MEorangered4 MEsienna3
#   <chr>        <chr>        <chr>
# 1 down         down         mixed
# 2 down         down         up
# 3 down         down         down
# # A tibble: 2 × 8
#   group   MEdarkmagenta MEdarkorange MEdarkturquoise MElightcyan MElightgreen
#   <chr>   <chr>         <chr>        <chr>           <chr>       <chr>
# 1 ADNP_CR down          down         up              up          up
# 2 YY1_CR  down          down         up              up          up
#   MEorangered4 MEsienna3
#   <chr>        <chr>
# 1 up           down
# 2 up           down

# %%
# # add some constraints to account for nested values
# # Suppose relevant_module_eigengenes is a samples x modules matrix
# ME_sd <- apply(module_eigengenes, 2, sd, na.rm = TRUE)
# ME_sd_th<-mean(ME_sd)*0.5 #with gernal median
# # Compute per-module SD across all samples
# ME_sd <- apply(relevant_module_eigengenes, 2, sd, na.rm = TRUE)

# # Define per-module threshold (30% of module SD)
# ME_sd_th_module <- ME_sd * 0.3
# # function: run Wilcoxon tests per cluster
# test_cluster_wilcox_consistent <- function(cluster_name, cluster_samples, ME_matrix, sampleTable_measeq, prop_threshold = 0.8) {
#   # ---------------------------
#   # 1. subset eigengenes for cluster
#   # ---------------------------
#   ME_sub <- ME_matrix[cluster_samples, , drop = FALSE]
  
#   # ---------------------------
#   # 2. Wilcoxon test per module
#   # ---------------------------
#   results <- apply(ME_sub, 2, function(x) {
#     wt <- suppressWarnings(wilcox.test(x, mu = 0))  # warning suppressed for ties
#     c(median = median(x),
#       p = wt$p.value)
#   })
  
#   df <- as.data.frame(t(results))
#   df$module <- rownames(df)
#   df$p_adj <- p.adjust(df$p, method = "fdr")
#   df$threshold <- ME_sd_th_module[as.character(df$module)]

#   # assign direction based on median
#   df <- df %>%
#     mutate(direction = case_when(
#       p < 0.05 & median > threshold  ~ "up",
#       p < 0.05 & median < -threshold  ~ "down",
#       TRUE ~ "ns"
#     ))
  
#   # ---------------------------
#   # 3. Prepare ME_df with sample and group info
#   # ---------------------------
#   ME_df <- ME_sub %>%
#     as.data.frame() %>%
#     rownames_to_column("sample_show") %>%
#     left_join(sampleTable_measeq[, c("sample_show", "group")], by = "sample_show")
  
#   # ---------------------------
#   # 4. Compute per-cell-line proportion-based consistency
#   # ---------------------------
#   group_sign <- function(x, prop_threshold) {
#     prop_pos <- mean(x > 0, na.rm = TRUE)
#     prop_neg <- mean(x < 0, na.rm = TRUE)
    
#     if (prop_pos >= prop_threshold) {
#       "up"
#     } else if (prop_neg >= prop_threshold) {
#       "down"
#     } else {
#       "mixed"
#     }
#   }
  
#   ME_by_group <- ME_df %>%
#     group_by(group) %>%
#     summarise(across(where(is.numeric), ~ group_sign(.x, prop_threshold)), .groups = "drop")
  
#   print(ME_by_group, width = Inf)  # inspect per-cell-line consistency
  
#   # ---------------------------
#   # 5. Across-group consistency
#   # ---------------------------
#   consistency <- apply(ME_by_group[,-1], 2, function(vals) {
#     if (all(vals == "up")) {
#       "up"
#     } else if (all(vals == "down")) {
#       "down"
#     } else {
#       "mixed"
#     }
#   })
  
#   df$consistent_direction <- consistency[df$module]
  
#   # stricter significance: Wilcoxon significant AND consistent across groups
#   df <- df %>%
#     mutate(consistent_significance = case_when(
#       direction == "up" & consistent_direction == "up" ~ "up",
#       direction == "down" & consistent_direction == "down" ~ "down",
#       TRUE ~ "ns"
#     ))
  
#   # assign cluster name
#   df$cluster <- cluster_name
  
#   df
# }

# # ---------------------------
# # 6. Run per cluster
# # ---------------------------
# cluster_results <- purrr::imap(trn_clusters, 
#                                 ~ test_cluster_wilcox_consistent(.y, .x,
#                                     ME_matrix = relevant_module_eigengenes,
#                                     sampleTable_measeq = sampleTable_measeq,
#                                     prop_threshold = 0.8))  # 80% replicates agreement
# cluster_results <- do.call(rbind, cluster_results)
# write.csv(cluster_results,"gene_modules_cluster_wilcox_th_sd03_prop08.csv")

# %%
getwd()
# Out:
# [1] "T:/PIgroup Nael NadifKasri/Sofia/2025/MEA_seq_patient/Analysis/MEA-seq/WGCNA_sPLSR"

# %%
head(full_signature_ordered)
# Out:
# [1] "CYP26B1" "CD9"     "AGPS"    "HGF"     "PEX3"    "SLC18A1"

# %%
# -------------------------------
# Determine module order from module eigengene heatmap
# -------------------------------
module_order <- colnames(relevant_module_eigengenes)[p$tree_col$order]  # order of modules in pheatmap

# Order genes within modules based on module_order
genes_modules_ordered <- genes_modules[genes_modules$module %in% module_order, ]
genes_modules_ordered$module <- factor(genes_modules_ordered$module, levels = module_order)

# Order full_signature based on module order
full_signature_ordered <- unlist(lapply(module_order, function(mod) {
  genes_modules_ordered$gene[genes_modules_ordered$module == mod]
}), use.names = FALSE)

# %%
head(norm.counts_df_corder_sc)
# Out:
#                       TSPAN6     TNMD       DPM1       SCYL3      C1orf112
# SMARCB1_KSS_E1         1.1017816 0.02478544 -0.6862123 -1.2972676  0.3400366
# SMARCB1_KSS_F3         1.3736473 0.03894595 -1.9921782 -1.1967026 -2.2725814
# SMARCB1_KSS_E2         0.2301165 0.39799634 -0.7198951 -0.9907763  0.1126861
# SMARCB1_KSS-CRISPR_F7  0.7693492 0.49515347 -1.5592388  0.6095159 -0.2564588
# SMARCB1_KSS-CRISPR_F8  0.7633635 0.68499405 -0.9549354  0.1337096 -0.5398244
# CHD8_C3_F3            -0.1347079 0.79880137  0.4484424 -0.2554670 -1.3041503
#                       FGR        CFH        FUCA2       GCLC       NFYA       ⋯
# SMARCB1_KSS_E1         1.1402179 -2.3647154  0.04851368 -0.4443534 -0.6719188 ⋯
# SMARCB1_KSS_F3        -1.9734906 -0.6580245  0.35796816 -0.5969174 -0.8190148 ⋯
# SMARCB1_KSS_E2        -0.8029487 -0.7211237 -0.36382617 -0.5889208 -1.6166279 ⋯
# SMARCB1_KSS-CRISPR_F7  0.2650953  0.4587042 -0.50316568 -0.2984949 -0.2271807 ⋯
# SMARCB1_KSS-CRISPR_F8  1.5472694  0.4486263  0.09366890 -1.5439744 -0.7271859 ⋯
# CHD8_C3_F3            -1.8205485 -0.5647814  0.31913606  1.8222376 -0.8962782 ⋯
#                       NPBWR1     CDR1        PANO1       PRRC2B      F8A1
# SMARCB1_KSS_E1         0.5201972 -0.95685028 -0.09814186  0.31503417  0.3424877
# SMARCB1_KSS_F3         0.3613699  0.56137532  1.02766765 -0.19206404 -0.6645737
# SMARCB1_KSS_E2        -0.3107140  1.30717940 -2.56338857  0.25022326  0.1783006
# SMARCB1_KSS-CRISPR_F7 -0.1393673  0.08670255 -0.30194901 -0.02567161  0.3084269
# SMARCB1_KSS-CRISPR_F8 -0.1490734  0.17417991  0.52077007  0.19713250  0.8273238
# CHD8_C3_F3             0.7024797 -0.47302762  0.40207616 -0.69610887  0.4232423
#                       ARHGAP11A-SCG5 LSP1P5     RPSAP58    LINC01530
# SMARCB1_KSS_E1        -0.5391359     -1.7536812  0.1596491 -1.8800708
# SMARCB1_KSS_F3        -0.8237406     -2.8786495 -0.9008958 -1.0553782
# SMARCB1_KSS_E2        -0.7579899     -0.2889781 -0.6786586 -1.3092543
# SMARCB1_KSS-CRISPR_F7  1.7011412      1.0965665  0.7522453 -1.4215581
# SMARCB1_KSS-CRISPR_F8 -0.8967907      2.6764689  0.1739086  0.8456757
# CHD8_C3_F3            -0.7786439     -1.0614747 -1.7487037  0.9014307
#                       LINC01512
# SMARCB1_KSS_E1         0.7876488
# SMARCB1_KSS_F3         0.2391309
# SMARCB1_KSS_E2         0.1186621
# SMARCB1_KSS-CRISPR_F7  0.3358357
# SMARCB1_KSS-CRISPR_F8  1.2597289
# CHD8_C3_F3            -1.4153850

# %%
 
# Prepare normalized counts for relevant genes
# -------------------------------
samples_order_no_outlier <- setdiff(row_names_ordered, "SMARCB1_2_D7")
norm_counts_subset <- norm.counts_df_corder_sc[samples_order_no_outlier, colnames(norm.counts_df_corder_sc) %in% full_signature_ordered]

# Scale per gene (optional)
norm_counts_scaled <- norm_counts_subset

# Melt for ggplot
select <- melt(norm_counts_scaled)
colnames(select) <- c("sample_show", "gene", "expression")

# Add module info
select$module <- genes_modules_ordered$module[match(select$gene, genes_modules_ordered$gene)]
select$gene <- factor(select$gene, levels = rev(full_signature_ordered))

# Order samples by previous module eigengene heatmap
select$sample_show <- factor(select$sample_show, levels = samples_order_no_outlier)

# Prepare color vector for y-axis labels
gene_colors <- genes_modules_ordered$module[match(levels(select$gene), genes_modules_ordered$gene)]
gene_colors <- gsub("^ME", "", gene_colors)

# %%
#

# -------------------------------
# Plot heatmap
# -------------------------------
p <- ggplot(select, aes(x = sample_show, y = gene, fill = expression)) +
  geom_tile() +
  scale_fill_gradient2(low = "blue", mid = "black", high = "yellow", limits = c(-2.5, 2.5)) +
  theme(
    panel.grid = element_blank(),
    panel.background = element_blank(),
    axis.line = element_line(colour = "white"),
    axis.text.y = element_text(size = 2, colour = gene_colors, angle = 180, hjust = 0, vjust = 1, face = "italic"),
    axis.text.x = element_text(angle = 90, size = 3, hjust = 1, vjust = 0.5),
    axis.text = element_text(color = "black"),
    legend.key.size = unit(0.5, "cm"),
    legend.key.height = unit(0.25, "cm"),
    legend.key.width = unit(0.25, "cm"),
    legend.text = element_text(size = 4, angle = 0, color = "white"),
    axis.title = element_text(size = 0),
    axis.ticks.y = element_blank(),
    axis.ticks.length = unit(0, "cm")
  ) +
  labs(fill = "") +
  ylab(" ")
p
ggsave("Heatmap_full_signature_clusters.pdf",bg = "transparent",
                  width = 3,   # inches
                  height = 3,   # inches
                plot=p
            )
# Out:
# Warning message:
# "Vectorized input to `element_text()` is not officially supported.
# ℹ Results may be unexpected or may change in future versions of ggplot2."
# plot without title
